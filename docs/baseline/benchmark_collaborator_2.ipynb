# %%
import logging

from fed_avg_schd import BenchFedAvg
from fed_prox_schd import BenchFedProx

from alphafed import logger, mock_context

logger.setLevel(logging.INFO)

# 算法实际运行时会从任务管理器获取任务参与节点的 Node ID 列表，但是在模拟环境不能通过
# 访问实际接口获得这个信息，所以需要通过 nodes 参数将这个列表配置在模拟环境中。
aggregator_id = 'b9003d53-1aba-4b1d-9af7-270367c68066'  # 设置一个假想 ID
col_id_1 = '6777d66c-08ac-4706-9548-5ad9087e61d6'  # 设置一个假想 ID
col_id_2 = 'fab71b71-46bd-4b12-b9df-c396d4e1daca'  # 设置一个假想 ID

# %% [markdown]
# # 使用 FedAvg 完成一次训练，并记录相关评估结果

# %%
# 聚合方的模拟启动脚本
scheduler = BenchFedAvg(
    dataset_client_ids=list(range(2, 11, 2)),
    max_rounds=10,  # 受本地资源限制，运行速度可能会很慢，调试时不建议设置太高
    log_rounds=1
)

task_id = 'd7e0c597-0acb-4b2f-aa3e-6ad6781095e5'  # 设置一个假想 ID
with mock_context(id=col_id_2, nodes=[aggregator_id, col_id_1, col_id_2]):
    scheduler._run(id=col_id_2, task_id=task_id)
# Out:
# 2023-05-24 09:05:34,306|INFO|scheduler|push_log|143:
# Begin to validate local context.
# 2023-05-24 09:05:34,307|INFO|scheduler|push_log|143:
# Local context is ready.
# 2023-05-24 09:05:34,308|INFO|scheduler|push_log|143:
# Node fab71b71-46bd-4b12-b9df-c396d4e1daca is up.
# 2023-05-24 09:05:34,308|INFO|scheduler|push_log|143:
# Checking in the task ...
# 2023-05-24 09:05:35,320|INFO|scheduler|push_log|143:
# Node fab71b71-46bd-4b12-b9df-c396d4e1daca have taken part in the task.
# 2023-05-24 09:05:35,321|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:05:35,321|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:05:35,327|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:05:35,327|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 1
# 2023-05-24 09:05:35,327|INFO|scheduler|push_log|143:
# Waiting for training of round 1 begin ...
# 2023-05-24 09:05:36,331|INFO|scheduler|push_log|143:
# Training of round 1 begins.
# 2023-05-24 09:05:36,331|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:05:36,750|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:05:36,752|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:05:36,753|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:05:38,614|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.861 秒
# 2023-05-24 09:05:38,615|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:05:38,615|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:05:38,619|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:05:39,822|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:05:39,822|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 1 ...
# 2023-05-24 09:05:42,828|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 1.
# 2023-05-24 09:05:42,829|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:05:42,829|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:05:42,834|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:05:42,835|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 2
# 2023-05-24 09:05:42,835|INFO|scheduler|push_log|143:
# Waiting for training of round 2 begin ...
# 2023-05-24 09:05:43,839|INFO|scheduler|push_log|143:
# Training of round 2 begins.
# 2023-05-24 09:05:43,840|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:05:44,259|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:05:44,261|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:05:44,261|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:05:45,965|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.704 秒
# 2023-05-24 09:05:45,966|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:05:45,967|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:05:45,972|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:05:47,074|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:05:47,075|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 2 ...
# 2023-05-24 09:05:50,085|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 2.
# 2023-05-24 09:05:50,086|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:05:50,086|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:05:50,092|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:05:50,093|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 3
# 2023-05-24 09:05:50,093|INFO|scheduler|push_log|143:
# Waiting for training of round 3 begin ...
# 2023-05-24 09:05:51,097|INFO|scheduler|push_log|143:
# Training of round 3 begins.
# 2023-05-24 09:05:51,098|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:05:51,520|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:05:51,523|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:05:51,523|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:05:53,234|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.710 秒
# 2023-05-24 09:05:53,235|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:05:53,236|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:05:53,241|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:05:54,444|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:05:54,445|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 3 ...
# 2023-05-24 09:05:56,450|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 3.
# 2023-05-24 09:05:56,450|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:05:56,451|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:05:56,456|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:05:56,457|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 4
# 2023-05-24 09:05:56,457|INFO|scheduler|push_log|143:
# Waiting for training of round 4 begin ...
# 2023-05-24 09:05:57,461|INFO|scheduler|push_log|143:
# Training of round 4 begins.
# 2023-05-24 09:05:57,462|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:05:58,087|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:05:58,090|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:05:58,090|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:05:59,866|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.776 秒
# 2023-05-24 09:05:59,867|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:05:59,868|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:05:59,874|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:01,076|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:01,077|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 4 ...
# 2023-05-24 09:06:02,081|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 4.
# 2023-05-24 09:06:02,081|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:02,082|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:02,087|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:02,088|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 5
# 2023-05-24 09:06:02,088|INFO|scheduler|push_log|143:
# Waiting for training of round 5 begin ...
# 2023-05-24 09:06:03,092|INFO|scheduler|push_log|143:
# Training of round 5 begins.
# 2023-05-24 09:06:03,093|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:03,514|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:03,515|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:03,516|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:05,278|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.762 秒
# 2023-05-24 09:06:05,280|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:05,280|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:05,285|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:06,487|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:06,488|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 5 ...
# 2023-05-24 09:06:08,493|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 5.
# 2023-05-24 09:06:08,494|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:08,494|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:08,500|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:08,500|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 6
# 2023-05-24 09:06:08,501|INFO|scheduler|push_log|143:
# Waiting for training of round 6 begin ...
# 2023-05-24 09:06:09,505|INFO|scheduler|push_log|143:
# Training of round 6 begins.
# 2023-05-24 09:06:09,505|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:09,923|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:09,925|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:09,926|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:11,680|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.754 秒
# 2023-05-24 09:06:11,681|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:11,682|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:11,686|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:12,889|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:12,890|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 6 ...
# 2023-05-24 09:06:14,895|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 6.
# 2023-05-24 09:06:14,896|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:14,896|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:14,901|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:14,902|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 7
# 2023-05-24 09:06:14,902|INFO|scheduler|push_log|143:
# Waiting for training of round 7 begin ...
# 2023-05-24 09:06:15,906|INFO|scheduler|push_log|143:
# Training of round 7 begins.
# 2023-05-24 09:06:15,906|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:16,219|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:16,221|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:16,221|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:17,978|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.757 秒
# 2023-05-24 09:06:17,980|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:17,980|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:17,985|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:19,187|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:19,188|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 7 ...
# 2023-05-24 09:06:21,193|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 7.
# 2023-05-24 09:06:21,194|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:21,194|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:21,200|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:21,200|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 8
# 2023-05-24 09:06:21,200|INFO|scheduler|push_log|143:
# Waiting for training of round 8 begin ...
# 2023-05-24 09:06:22,204|INFO|scheduler|push_log|143:
# Training of round 8 begins.
# 2023-05-24 09:06:22,205|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:22,624|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:22,626|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:22,626|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:24,335|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.708 秒
# 2023-05-24 09:06:24,336|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:24,337|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:24,342|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:25,545|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:25,545|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 8 ...
# 2023-05-24 09:06:27,551|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 8.
# 2023-05-24 09:06:27,552|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:27,552|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:27,557|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:27,558|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 9
# 2023-05-24 09:06:27,558|INFO|scheduler|push_log|143:
# Waiting for training of round 9 begin ...
# 2023-05-24 09:06:28,562|INFO|scheduler|push_log|143:
# Training of round 9 begins.
# 2023-05-24 09:06:28,563|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:28,985|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:28,987|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:28,987|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:30,665|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.678 秒
# 2023-05-24 09:06:30,666|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:30,667|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:30,671|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:31,874|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:31,875|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 9 ...
# 2023-05-24 09:06:33,880|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 9.
# 2023-05-24 09:06:33,881|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:33,881|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:33,886|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:33,887|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 10
# 2023-05-24 09:06:33,887|INFO|scheduler|push_log|143:
# Waiting for training of round 10 begin ...
# 2023-05-24 09:06:34,891|INFO|scheduler|push_log|143:
# Training of round 10 begins.
# 2023-05-24 09:06:34,891|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:35,208|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:35,210|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:35,210|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:36,906|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.696 秒
# 2023-05-24 09:06:36,907|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:36,908|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:36,912|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:38,115|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:38,116|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 10 ...
# 2023-05-24 09:06:40,121|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 10.
# 2023-05-24 09:06:40,122|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:40,122|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:40,125|INFO|fed_avg|_launch_process|352:
# training task complete

# %% [markdown]
# # 使用 FedProx 完成一次训练，设置 mu 值为 0.01，并记录相关评估结果

# %%
scheduler = BenchFedProx(
    dataset_client_ids=list(range(2, 11, 2)),
    max_rounds=10,
    mu=0.01,
    log_rounds=1
)

task_id = 'f12d8260-8df8-4a44-a4a4-335a68fd85d7'  # 设置一个假想 ID
with mock_context(id=col_id_2, nodes=[aggregator_id, col_id_1, col_id_2]):
    scheduler._run(id=col_id_2, task_id=task_id)
# Out:
# 2023-05-24 09:07:09,562|INFO|scheduler|push_log|143:
# Begin to validate local context.
# 2023-05-24 09:07:09,563|INFO|scheduler|push_log|143:
# Local context is ready.
# 2023-05-24 09:07:09,564|INFO|scheduler|push_log|143:
# Node fab71b71-46bd-4b12-b9df-c396d4e1daca is up.
# 2023-05-24 09:07:09,564|INFO|scheduler|push_log|143:
# Checking in the task ...
# 2023-05-24 09:07:10,575|INFO|scheduler|push_log|143:
# Node fab71b71-46bd-4b12-b9df-c396d4e1daca have taken part in the task.
# 2023-05-24 09:07:10,576|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:10,576|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:10,581|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:10,581|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 1
# 2023-05-24 09:07:10,582|INFO|scheduler|push_log|143:
# Waiting for training of round 1 begin ...
# 2023-05-24 09:07:11,586|INFO|scheduler|push_log|143:
# Training of round 1 begins.
# 2023-05-24 09:07:11,587|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:11,904|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:11,905|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:11,906|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-images-idx3-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-images-idx3-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/train-images-idx3-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-labels-idx1-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-labels-idx1-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/train-labels-idx1-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-images-idx3-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-images-idx3-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/t10k-images-idx3-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-labels-idx1-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-labels-idx1-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/t10k-labels-idx1-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw
# 2023-05-24 09:07:15,619|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 3.713 秒
# 2023-05-24 09:07:15,620|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:15,621|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:15,626|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:16,829|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:16,830|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 1 ...
# 2023-05-24 09:07:20,837|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 1.
# 2023-05-24 09:07:20,838|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:20,839|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:20,844|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:20,844|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 2
# 2023-05-24 09:07:20,844|INFO|scheduler|push_log|143:
# Waiting for training of round 2 begin ...
# 2023-05-24 09:07:21,848|INFO|scheduler|push_log|143:
# Training of round 2 begins.
# 2023-05-24 09:07:21,849|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:23,269|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:23,271|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:23,272|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:25,028|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.755 秒
# 2023-05-24 09:07:25,029|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:25,029|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:25,034|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:26,236|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:26,237|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 2 ...
# 2023-05-24 09:07:28,242|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 2.
# 2023-05-24 09:07:28,243|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:28,243|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:28,249|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:28,249|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 3
# 2023-05-24 09:07:28,249|INFO|scheduler|push_log|143:
# Waiting for training of round 3 begin ...
# 2023-05-24 09:07:29,253|INFO|scheduler|push_log|143:
# Training of round 3 begins.
# 2023-05-24 09:07:29,254|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:29,672|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:29,675|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:29,675|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:31,440|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.765 秒
# 2023-05-24 09:07:31,441|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:31,442|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:31,447|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:32,649|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:32,650|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 3 ...
# 2023-05-24 09:07:33,654|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 3.
# 2023-05-24 09:07:33,655|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:33,655|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:33,665|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:33,665|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 4
# 2023-05-24 09:07:33,666|INFO|scheduler|push_log|143:
# Waiting for training of round 4 begin ...
# 2023-05-24 09:07:34,672|INFO|scheduler|push_log|143:
# Training of round 4 begins.
# 2023-05-24 09:07:34,672|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:34,991|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:34,995|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:34,996|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:36,798|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.802 秒
# 2023-05-24 09:07:36,799|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:36,800|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:36,804|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:38,007|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:38,008|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 4 ...
# 2023-05-24 09:07:40,012|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 4.
# 2023-05-24 09:07:40,013|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:40,013|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:40,019|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:40,019|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 5
# 2023-05-24 09:07:40,019|INFO|scheduler|push_log|143:
# Waiting for training of round 5 begin ...
# 2023-05-24 09:07:41,023|INFO|scheduler|push_log|143:
# Training of round 5 begins.
# 2023-05-24 09:07:41,023|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:41,444|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:41,445|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:41,446|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:43,198|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.751 秒
# 2023-05-24 09:07:43,199|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:43,199|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:43,203|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:44,406|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:44,407|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 5 ...
# 2023-05-24 09:07:46,412|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 5.
# 2023-05-24 09:07:46,412|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:46,413|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:46,418|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:46,418|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 6
# 2023-05-24 09:07:46,419|INFO|scheduler|push_log|143:
# Waiting for training of round 6 begin ...
# 2023-05-24 09:07:47,423|INFO|scheduler|push_log|143:
# Training of round 6 begins.
# 2023-05-24 09:07:47,423|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:47,853|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:47,854|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:47,855|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:49,576|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.721 秒
# 2023-05-24 09:07:49,577|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:49,578|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:49,583|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:50,785|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:50,786|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 6 ...
# 2023-05-24 09:07:51,790|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 6.
# 2023-05-24 09:07:51,791|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:51,791|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:51,796|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:51,797|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 7
# 2023-05-24 09:07:51,797|INFO|scheduler|push_log|143:
# Waiting for training of round 7 begin ...
# 2023-05-24 09:07:52,801|INFO|scheduler|push_log|143:
# Training of round 7 begins.
# 2023-05-24 09:07:52,802|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:53,164|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:53,166|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:53,167|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:54,900|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.732 秒
# 2023-05-24 09:07:54,901|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:54,902|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:54,906|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:56,009|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:56,010|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 7 ...
# 2023-05-24 09:07:58,014|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 7.
# 2023-05-24 09:07:58,015|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:58,015|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:58,020|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:58,021|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 8
# 2023-05-24 09:07:58,021|INFO|scheduler|push_log|143:
# Waiting for training of round 8 begin ...
# 2023-05-24 09:07:59,024|INFO|scheduler|push_log|143:
# Training of round 8 begins.
# 2023-05-24 09:07:59,025|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:59,342|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:59,344|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:59,344|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:08:00,995|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.650 秒
# 2023-05-24 09:08:00,996|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:08:00,997|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:08:01,002|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:08:02,205|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:08:02,205|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 8 ...
# 2023-05-24 09:08:04,211|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 8.
# 2023-05-24 09:08:04,211|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:04,212|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:04,217|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:08:04,217|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 9
# 2023-05-24 09:08:04,218|INFO|scheduler|push_log|143:
# Waiting for training of round 9 begin ...
# 2023-05-24 09:08:05,222|INFO|scheduler|push_log|143:
# Training of round 9 begins.
# 2023-05-24 09:08:05,222|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:08:05,643|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:08:05,645|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:08:05,645|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:08:07,380|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.734 秒
# 2023-05-24 09:08:07,381|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:08:07,382|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:08:07,387|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:08:08,590|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:08:08,590|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 9 ...
# 2023-05-24 09:08:11,597|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 9.
# 2023-05-24 09:08:11,598|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:11,598|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:11,603|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:08:11,603|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 10
# 2023-05-24 09:08:11,604|INFO|scheduler|push_log|143:
# Waiting for training of round 10 begin ...
# 2023-05-24 09:08:12,608|INFO|scheduler|push_log|143:
# Training of round 10 begins.
# 2023-05-24 09:08:12,609|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:08:13,028|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:08:13,032|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:08:13,033|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:08:14,798|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.764 秒
# 2023-05-24 09:08:14,799|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:08:14,799|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:08:14,804|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:08:15,906|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:08:15,906|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 10 ...
# 2023-05-24 09:08:17,911|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 10.
# 2023-05-24 09:08:17,912|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:17,912|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:17,915|INFO|fed_avg|_launch_process|352:
# training task complete

# %% [markdown]
# # 使用 FedProx 完成一次训练，设置 mu 值为 0.05，并记录相关评估结果

# %%
scheduler = BenchFedProx(
    dataset_client_ids=list(range(2, 11, 2)),
    max_rounds=10,
    mu=0.05,
    log_rounds=1
)

task_id = '602476f9-7aec-4d6c-9524-fef10b768c2e'  # 设置一个假想 ID
with mock_context(id=col_id_2, nodes=[aggregator_id, col_id_1, col_id_2]):
    scheduler._run(id=col_id_2, task_id=task_id)
# Out:
# 2023-05-24 09:08:47,937|INFO|scheduler|push_log|143:
# Begin to validate local context.
# 2023-05-24 09:08:47,937|INFO|scheduler|push_log|143:
# Local context is ready.
# 2023-05-24 09:08:47,938|INFO|scheduler|push_log|143:
# Node fab71b71-46bd-4b12-b9df-c396d4e1daca is up.
# 2023-05-24 09:08:47,938|INFO|scheduler|push_log|143:
# Checking in the task ...
# 2023-05-24 09:08:48,949|INFO|scheduler|push_log|143:
# Node fab71b71-46bd-4b12-b9df-c396d4e1daca have taken part in the task.
# 2023-05-24 09:08:48,950|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:48,950|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:48,955|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:08:48,956|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 1
# 2023-05-24 09:08:48,956|INFO|scheduler|push_log|143:
# Waiting for training of round 1 begin ...
# 2023-05-24 09:08:49,960|INFO|scheduler|push_log|143:
# Training of round 1 begins.
# 2023-05-24 09:08:49,960|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:08:50,382|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:08:50,386|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:08:50,386|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-images-idx3-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-images-idx3-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/train-images-idx3-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-labels-idx1-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-labels-idx1-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/train-labels-idx1-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-images-idx3-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-images-idx3-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/t10k-images-idx3-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-labels-idx1-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-labels-idx1-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/t10k-labels-idx1-ubyte.gz to ./fab71b71-46bd-4b12-b9df-c396d4e1daca/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw
# 2023-05-24 09:08:54,192|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 3.805 秒
# 2023-05-24 09:08:54,193|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:08:54,194|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:08:54,199|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:08:55,401|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:08:55,402|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 1 ...
# 2023-05-24 09:08:59,410|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 1.
# 2023-05-24 09:08:59,411|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:59,411|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:59,416|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:08:59,417|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 2
# 2023-05-24 09:08:59,417|INFO|scheduler|push_log|143:
# Waiting for training of round 2 begin ...
# 2023-05-24 09:09:00,421|INFO|scheduler|push_log|143:
# Training of round 2 begins.
# 2023-05-24 09:09:00,422|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:00,840|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:00,842|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:00,843|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:02,597|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.753 秒
# 2023-05-24 09:09:02,598|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:02,598|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:02,602|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:03,805|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:03,806|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 2 ...
# 2023-05-24 09:09:05,811|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 2.
# 2023-05-24 09:09:05,812|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:05,812|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:05,817|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:05,818|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 3
# 2023-05-24 09:09:05,818|INFO|scheduler|push_log|143:
# Waiting for training of round 3 begin ...
# 2023-05-24 09:09:06,822|INFO|scheduler|push_log|143:
# Training of round 3 begins.
# 2023-05-24 09:09:06,823|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:07,139|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:07,141|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:07,141|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:08,920|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.778 秒
# 2023-05-24 09:09:08,921|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:08,921|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:08,926|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:10,128|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:10,129|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 3 ...
# 2023-05-24 09:09:11,133|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 3.
# 2023-05-24 09:09:11,134|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:11,134|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:11,139|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:11,140|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 4
# 2023-05-24 09:09:11,140|INFO|scheduler|push_log|143:
# Waiting for training of round 4 begin ...
# 2023-05-24 09:09:12,144|INFO|scheduler|push_log|143:
# Training of round 4 begins.
# 2023-05-24 09:09:12,145|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:12,460|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:12,465|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:12,465|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:14,195|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.729 秒
# 2023-05-24 09:09:14,196|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:14,198|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:14,203|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:15,405|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:15,406|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 4 ...
# 2023-05-24 09:09:17,411|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 4.
# 2023-05-24 09:09:17,412|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:17,412|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:17,417|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:17,418|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 5
# 2023-05-24 09:09:17,418|INFO|scheduler|push_log|143:
# Waiting for training of round 5 begin ...
# 2023-05-24 09:09:18,422|INFO|scheduler|push_log|143:
# Training of round 5 begins.
# 2023-05-24 09:09:18,423|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:18,736|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:18,740|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:18,740|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:20,465|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.725 秒
# 2023-05-24 09:09:20,466|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:20,467|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:20,471|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:21,674|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:21,674|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 5 ...
# 2023-05-24 09:09:23,680|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 5.
# 2023-05-24 09:09:23,680|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:23,681|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:23,686|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:23,686|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 6
# 2023-05-24 09:09:23,687|INFO|scheduler|push_log|143:
# Waiting for training of round 6 begin ...
# 2023-05-24 09:09:24,691|INFO|scheduler|push_log|143:
# Training of round 6 begins.
# 2023-05-24 09:09:24,691|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:25,105|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:25,109|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:25,110|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:26,833|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.722 秒
# 2023-05-24 09:09:26,834|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:26,834|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:26,839|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:27,941|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:27,942|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 6 ...
# 2023-05-24 09:09:29,947|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 6.
# 2023-05-24 09:09:29,948|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:29,948|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:29,953|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:29,954|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 7
# 2023-05-24 09:09:29,954|INFO|scheduler|push_log|143:
# Waiting for training of round 7 begin ...
# 2023-05-24 09:09:30,959|INFO|scheduler|push_log|143:
# Training of round 7 begins.
# 2023-05-24 09:09:30,960|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:31,279|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:31,284|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:31,284|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:33,035|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.751 秒
# 2023-05-24 09:09:33,036|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:33,037|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:33,041|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:34,243|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:34,244|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 7 ...
# 2023-05-24 09:09:35,247|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 7.
# 2023-05-24 09:09:35,247|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:35,248|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:35,253|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:35,253|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 8
# 2023-05-24 09:09:35,254|INFO|scheduler|push_log|143:
# Waiting for training of round 8 begin ...
# 2023-05-24 09:09:36,257|INFO|scheduler|push_log|143:
# Training of round 8 begins.
# 2023-05-24 09:09:36,258|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:36,574|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:36,577|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:36,577|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:38,308|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.731 秒
# 2023-05-24 09:09:38,309|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:38,310|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:38,315|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:39,518|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:39,519|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 8 ...
# 2023-05-24 09:09:41,524|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 8.
# 2023-05-24 09:09:41,525|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:41,525|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:41,530|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:41,531|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 9
# 2023-05-24 09:09:41,531|INFO|scheduler|push_log|143:
# Waiting for training of round 9 begin ...
# 2023-05-24 09:09:42,535|INFO|scheduler|push_log|143:
# Training of round 9 begins.
# 2023-05-24 09:09:42,536|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:42,954|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:42,958|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:42,959|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:44,730|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.771 秒
# 2023-05-24 09:09:44,731|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:44,731|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:44,736|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:45,838|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:45,839|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 9 ...
# 2023-05-24 09:09:47,844|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 9.
# 2023-05-24 09:09:47,845|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:47,845|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:47,850|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:47,850|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 10
# 2023-05-24 09:09:47,851|INFO|scheduler|push_log|143:
# Waiting for training of round 10 begin ...
# 2023-05-24 09:09:48,855|INFO|scheduler|push_log|143:
# Training of round 10 begins.
# 2023-05-24 09:09:48,856|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:49,173|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:49,175|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:49,175|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:50,847|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.671 秒
# 2023-05-24 09:09:50,848|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:50,848|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:50,855|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:52,058|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:52,059|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 10 ...
# 2023-05-24 09:09:55,065|INFO|scheduler|push_log|143:
# ID: fab71b71-46bd-4b12-b9df-c396d4e1daca finished training task of round 10.
# 2023-05-24 09:09:55,066|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:55,066|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:55,069|INFO|fed_avg|_launch_process|352:
# training task complete
