# %%
import logging

from fed_avg_schd import BenchFedAvg
from fed_prox_schd import BenchFedProx

from alphafed import logger, mock_context

logger.setLevel(logging.INFO)

# 算法实际运行时会从任务管理器获取任务参与节点的 Node ID 列表，但是在模拟环境不能通过
# 访问实际接口获得这个信息，所以需要通过 nodes 参数将这个列表配置在模拟环境中。
aggregator_id = 'b9003d53-1aba-4b1d-9af7-270367c68066'  # 设置一个假想 ID
col_id_1 = '6777d66c-08ac-4706-9548-5ad9087e61d6'  # 设置一个假想 ID
col_id_2 = 'fab71b71-46bd-4b12-b9df-c396d4e1daca'  # 设置一个假想 ID

# %% [markdown]
# # 使用 FedAvg 完成一次训练，并记录相关评估结果

# %%
scheduler = BenchFedAvg(
    dataset_client_ids=list(range(1, 10, 2)),
    max_rounds=10,
    log_rounds=1
)

task_id = 'd7e0c597-0acb-4b2f-aa3e-6ad6781095e5'  # 设置一个假想 ID
with mock_context(id=col_id_1, nodes=[aggregator_id, col_id_1, col_id_2]):
    scheduler._run(id=col_id_1, task_id=task_id)
# Out:
# 2023-05-24 09:05:31,087|INFO|scheduler|push_log|143:
# Begin to validate local context.
# 2023-05-24 09:05:31,088|INFO|scheduler|push_log|143:
# Local context is ready.
# 2023-05-24 09:05:31,089|INFO|scheduler|push_log|143:
# Node 6777d66c-08ac-4706-9548-5ad9087e61d6 is up.
# 2023-05-24 09:05:31,089|INFO|scheduler|push_log|143:
# Checking in the task ...
# 2023-05-24 09:05:32,100|INFO|scheduler|push_log|143:
# Node 6777d66c-08ac-4706-9548-5ad9087e61d6 have taken part in the task.
# 2023-05-24 09:05:32,101|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:05:32,101|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:05:35,112|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:05:35,113|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 1
# 2023-05-24 09:05:35,113|INFO|scheduler|push_log|143:
# Waiting for training of round 1 begin ...
# 2023-05-24 09:05:36,117|INFO|scheduler|push_log|143:
# Training of round 1 begins.
# 2023-05-24 09:05:36,118|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:05:36,531|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:05:36,533|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:05:36,534|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:05:38,466|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.932 秒
# 2023-05-24 09:05:38,467|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:05:38,467|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:05:38,472|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:05:39,675|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:05:39,676|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 1 ...
# 2023-05-24 09:05:42,681|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 1.
# 2023-05-24 09:05:42,682|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:05:42,682|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:05:42,687|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:05:42,688|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 2
# 2023-05-24 09:05:42,688|INFO|scheduler|push_log|143:
# Waiting for training of round 2 begin ...
# 2023-05-24 09:05:43,692|INFO|scheduler|push_log|143:
# Training of round 2 begins.
# 2023-05-24 09:05:43,693|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:05:45,222|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:05:45,225|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:05:45,225|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:05:47,054|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.828 秒
# 2023-05-24 09:05:47,055|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:05:47,055|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:05:47,060|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:05:48,162|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:05:48,163|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 2 ...
# 2023-05-24 09:05:50,167|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 2.
# 2023-05-24 09:05:50,168|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:05:50,169|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:05:50,174|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:05:50,175|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 3
# 2023-05-24 09:05:50,175|INFO|scheduler|push_log|143:
# Waiting for training of round 3 begin ...
# 2023-05-24 09:05:51,179|INFO|scheduler|push_log|143:
# Training of round 3 begins.
# 2023-05-24 09:05:51,180|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:05:51,703|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:05:51,705|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:05:51,706|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:05:53,545|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.839 秒
# 2023-05-24 09:05:53,546|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:05:53,546|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:05:53,551|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:05:54,753|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:05:54,753|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 3 ...
# 2023-05-24 09:05:56,758|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 3.
# 2023-05-24 09:05:56,759|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:05:56,759|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:05:56,764|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:05:56,765|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 4
# 2023-05-24 09:05:56,765|INFO|scheduler|push_log|143:
# Waiting for training of round 4 begin ...
# 2023-05-24 09:05:57,769|INFO|scheduler|push_log|143:
# Training of round 4 begins.
# 2023-05-24 09:05:57,770|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:05:58,191|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:05:58,193|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:05:58,193|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:00,052|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.858 秒
# 2023-05-24 09:06:00,053|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:00,053|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:00,058|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:01,260|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:01,261|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 4 ...
# 2023-05-24 09:06:02,265|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 4.
# 2023-05-24 09:06:02,265|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:02,266|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:02,271|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:02,272|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 5
# 2023-05-24 09:06:02,272|INFO|scheduler|push_log|143:
# Waiting for training of round 5 begin ...
# 2023-05-24 09:06:03,277|INFO|scheduler|push_log|143:
# Training of round 5 begins.
# 2023-05-24 09:06:03,277|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:03,593|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:03,595|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:03,596|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:05,460|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.864 秒
# 2023-05-24 09:06:05,461|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:05,462|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:05,466|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:06,568|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:06,569|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 5 ...
# 2023-05-24 09:06:07,573|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 5.
# 2023-05-24 09:06:07,574|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:07,574|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:07,579|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:07,580|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 6
# 2023-05-24 09:06:07,580|INFO|scheduler|push_log|143:
# Waiting for training of round 6 begin ...
# 2023-05-24 09:06:08,585|INFO|scheduler|push_log|143:
# Training of round 6 begins.
# 2023-05-24 09:06:08,585|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:10,008|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:10,013|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:10,015|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:11,837|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.820 秒
# 2023-05-24 09:06:11,838|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:11,838|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:11,842|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:13,045|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:13,045|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 6 ...
# 2023-05-24 09:06:15,051|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 6.
# 2023-05-24 09:06:15,051|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:15,052|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:15,057|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:15,057|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 7
# 2023-05-24 09:06:15,058|INFO|scheduler|push_log|143:
# Waiting for training of round 7 begin ...
# 2023-05-24 09:06:16,062|INFO|scheduler|push_log|143:
# Training of round 7 begins.
# 2023-05-24 09:06:16,062|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:16,605|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:16,608|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:16,608|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:18,359|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.750 秒
# 2023-05-24 09:06:18,360|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:18,360|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:18,365|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:19,467|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:19,467|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 7 ...
# 2023-05-24 09:06:21,473|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 7.
# 2023-05-24 09:06:21,473|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:21,474|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:21,479|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:21,479|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 8
# 2023-05-24 09:06:21,479|INFO|scheduler|push_log|143:
# Waiting for training of round 8 begin ...
# 2023-05-24 09:06:22,483|INFO|scheduler|push_log|143:
# Training of round 8 begins.
# 2023-05-24 09:06:22,484|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:22,801|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:22,804|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:22,804|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:24,665|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.860 秒
# 2023-05-24 09:06:24,666|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:24,666|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:24,671|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:25,773|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:25,773|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 8 ...
# 2023-05-24 09:06:26,777|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 8.
# 2023-05-24 09:06:26,778|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:26,778|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:26,783|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:26,784|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 9
# 2023-05-24 09:06:26,784|INFO|scheduler|push_log|143:
# Waiting for training of round 9 begin ...
# 2023-05-24 09:06:27,788|INFO|scheduler|push_log|143:
# Training of round 9 begins.
# 2023-05-24 09:06:27,789|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:29,212|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:29,214|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:29,215|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:31,065|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.850 秒
# 2023-05-24 09:06:31,066|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:31,067|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:31,071|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:32,274|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:32,274|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 9 ...
# 2023-05-24 09:06:34,279|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 9.
# 2023-05-24 09:06:34,279|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:34,280|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:34,285|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:06:34,285|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 10
# 2023-05-24 09:06:34,285|INFO|scheduler|push_log|143:
# Waiting for training of round 10 begin ...
# 2023-05-24 09:06:35,289|INFO|scheduler|push_log|143:
# Training of round 10 begins.
# 2023-05-24 09:06:35,290|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:06:35,713|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:06:35,715|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:06:35,716|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:06:37,519|INFO|fed_avg_schd|train_an_epoch|58:
# 完成一轮训练，耗时 1.802 秒
# 2023-05-24 09:06:37,520|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:06:37,520|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:06:37,524|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:06:38,727|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:06:38,728|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 10 ...
# 2023-05-24 09:06:40,733|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 10.
# 2023-05-24 09:06:40,733|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:06:40,734|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:06:40,737|INFO|fed_avg|_launch_process|352:
# training task complete

# %% [markdown]
# # 使用 FedProx 完成一次训练，设置 mu 值为 0.01，并记录相关评估结果

# %%
scheduler = BenchFedProx(
    dataset_client_ids=list(range(1, 10, 2)),
    max_rounds=10,
    mu=0.01,
    log_rounds=1
)

task_id = 'f12d8260-8df8-4a44-a4a4-335a68fd85d7'  # 设置一个假想 ID
with mock_context(id=col_id_1, nodes=[aggregator_id, col_id_1, col_id_2]):
    scheduler._run(id=col_id_1, task_id=task_id)
# Out:
# 2023-05-24 09:07:03,277|INFO|scheduler|push_log|143:
# Begin to validate local context.
# 2023-05-24 09:07:03,277|INFO|scheduler|push_log|143:
# Local context is ready.
# 2023-05-24 09:07:03,278|INFO|scheduler|push_log|143:
# Node 6777d66c-08ac-4706-9548-5ad9087e61d6 is up.
# 2023-05-24 09:07:03,278|INFO|scheduler|push_log|143:
# Checking in the task ...
# 2023-05-24 09:07:04,287|INFO|scheduler|push_log|143:
# Node 6777d66c-08ac-4706-9548-5ad9087e61d6 have taken part in the task.
# 2023-05-24 09:07:04,288|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:04,288|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:11,304|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:11,305|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 1
# 2023-05-24 09:07:11,305|INFO|scheduler|push_log|143:
# Waiting for training of round 1 begin ...
# 2023-05-24 09:07:12,310|INFO|scheduler|push_log|143:
# Training of round 1 begins.
# 2023-05-24 09:07:12,311|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:12,737|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:12,741|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:12,742|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-images-idx3-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-images-idx3-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/train-images-idx3-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-labels-idx1-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-labels-idx1-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/train-labels-idx1-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-images-idx3-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-images-idx3-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/t10k-images-idx3-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-labels-idx1-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-labels-idx1-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw/t10k-labels-idx1-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/f12d8260-8df8-4a44-a4a4-335a68fd85d7/dataset/FedMNIST/raw
# 2023-05-24 09:07:16,414|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 3.672 秒
# 2023-05-24 09:07:16,415|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:16,416|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:16,420|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:17,623|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:17,623|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 1 ...
# 2023-05-24 09:07:21,631|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 1.
# 2023-05-24 09:07:21,632|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:21,632|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:21,637|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:21,637|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 2
# 2023-05-24 09:07:21,638|INFO|scheduler|push_log|143:
# Waiting for training of round 2 begin ...
# 2023-05-24 09:07:22,642|INFO|scheduler|push_log|143:
# Training of round 2 begins.
# 2023-05-24 09:07:22,642|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:23,063|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:23,067|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:23,068|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:24,917|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.849 秒
# 2023-05-24 09:07:24,919|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:24,919|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:24,924|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:26,127|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:26,127|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 2 ...
# 2023-05-24 09:07:28,132|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 2.
# 2023-05-24 09:07:28,133|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:28,133|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:28,139|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:28,139|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 3
# 2023-05-24 09:07:28,139|INFO|scheduler|push_log|143:
# Waiting for training of round 3 begin ...
# 2023-05-24 09:07:29,142|INFO|scheduler|push_log|143:
# Training of round 3 begins.
# 2023-05-24 09:07:29,143|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:29,569|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:29,574|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:29,574|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:31,442|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.868 秒
# 2023-05-24 09:07:31,443|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:31,444|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:31,449|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:32,651|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:32,652|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 3 ...
# 2023-05-24 09:07:33,657|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 3.
# 2023-05-24 09:07:33,658|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:33,658|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:33,668|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:33,668|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 4
# 2023-05-24 09:07:33,668|INFO|scheduler|push_log|143:
# Waiting for training of round 4 begin ...
# 2023-05-24 09:07:34,675|INFO|scheduler|push_log|143:
# Training of round 4 begins.
# 2023-05-24 09:07:34,675|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:34,992|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:34,995|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:34,996|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:36,874|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.878 秒
# 2023-05-24 09:07:36,875|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:36,875|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:36,880|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:38,082|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:38,083|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 4 ...
# 2023-05-24 09:07:40,088|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 4.
# 2023-05-24 09:07:40,089|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:40,089|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:40,094|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:40,095|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 5
# 2023-05-24 09:07:40,095|INFO|scheduler|push_log|143:
# Waiting for training of round 5 begin ...
# 2023-05-24 09:07:41,099|INFO|scheduler|push_log|143:
# Training of round 5 begins.
# 2023-05-24 09:07:41,099|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:41,413|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:41,415|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:41,416|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:43,294|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.878 秒
# 2023-05-24 09:07:43,295|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:43,296|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:43,300|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:44,502|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:44,503|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 5 ...
# 2023-05-24 09:07:46,508|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 5.
# 2023-05-24 09:07:46,509|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:46,509|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:46,515|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:46,515|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 6
# 2023-05-24 09:07:46,515|INFO|scheduler|push_log|143:
# Waiting for training of round 6 begin ...
# 2023-05-24 09:07:47,519|INFO|scheduler|push_log|143:
# Training of round 6 begins.
# 2023-05-24 09:07:47,520|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:47,938|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:47,943|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:47,943|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:49,796|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.852 秒
# 2023-05-24 09:07:49,797|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:49,797|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:49,802|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:50,904|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:50,904|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 6 ...
# 2023-05-24 09:07:51,909|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 6.
# 2023-05-24 09:07:51,909|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:51,910|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:51,915|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:51,915|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 7
# 2023-05-24 09:07:51,915|INFO|scheduler|push_log|143:
# Waiting for training of round 7 begin ...
# 2023-05-24 09:07:52,919|INFO|scheduler|push_log|143:
# Training of round 7 begins.
# 2023-05-24 09:07:52,920|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:53,360|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:53,363|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:53,364|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:07:55,182|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.817 秒
# 2023-05-24 09:07:55,183|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:07:55,183|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:07:55,188|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:07:56,390|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:07:56,391|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 7 ...
# 2023-05-24 09:07:57,395|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 7.
# 2023-05-24 09:07:57,395|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:07:57,395|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:07:57,401|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:07:57,401|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 8
# 2023-05-24 09:07:57,402|INFO|scheduler|push_log|143:
# Waiting for training of round 8 begin ...
# 2023-05-24 09:07:58,406|INFO|scheduler|push_log|143:
# Training of round 8 begins.
# 2023-05-24 09:07:58,406|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:07:59,834|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:07:59,836|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:07:59,837|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:08:01,674|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.837 秒
# 2023-05-24 09:08:01,675|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:08:01,676|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:08:01,680|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:08:02,882|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:08:02,883|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 8 ...
# 2023-05-24 09:08:04,888|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 8.
# 2023-05-24 09:08:04,889|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:04,889|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:04,894|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:08:04,894|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 9
# 2023-05-24 09:08:04,895|INFO|scheduler|push_log|143:
# Waiting for training of round 9 begin ...
# 2023-05-24 09:08:05,899|INFO|scheduler|push_log|143:
# Training of round 9 begins.
# 2023-05-24 09:08:05,900|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:08:06,326|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:08:06,329|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:08:06,329|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:08:08,146|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.816 秒
# 2023-05-24 09:08:08,147|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:08:08,148|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:08:08,152|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:08:09,354|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:08:09,355|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 9 ...
# 2023-05-24 09:08:11,360|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 9.
# 2023-05-24 09:08:11,361|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:11,361|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:11,367|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:08:11,367|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 10
# 2023-05-24 09:08:11,367|INFO|scheduler|push_log|143:
# Waiting for training of round 10 begin ...
# 2023-05-24 09:08:12,371|INFO|scheduler|push_log|143:
# Training of round 10 begins.
# 2023-05-24 09:08:12,372|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:08:12,686|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:08:12,688|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:08:12,689|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:08:14,522|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.833 秒
# 2023-05-24 09:08:14,523|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:08:14,524|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:08:14,529|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:08:15,631|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:08:15,631|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 10 ...
# 2023-05-24 09:08:17,636|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 10.
# 2023-05-24 09:08:17,637|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:17,637|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:17,640|INFO|fed_avg|_launch_process|352:
# training task complete

# %% [markdown]
# # 使用 FedProx 完成一次训练，设置 mu 值为 0.05，并记录相关评估结果

# %%
scheduler = BenchFedProx(
    dataset_client_ids=list(range(1, 10, 2)),
    max_rounds=10,
    mu=0.05,
    log_rounds=1
)

task_id = '602476f9-7aec-4d6c-9524-fef10b768c2e'  # 设置一个假想 ID
with mock_context(id=col_id_1, nodes=[aggregator_id, col_id_1, col_id_2]):
    scheduler._run(id=col_id_1, task_id=task_id)
# Out:
# 2023-05-24 09:08:34,117|INFO|scheduler|push_log|143:
# Begin to validate local context.
# 2023-05-24 09:08:34,117|INFO|scheduler|push_log|143:
# Local context is ready.
# 2023-05-24 09:08:34,118|INFO|scheduler|push_log|143:
# Node 6777d66c-08ac-4706-9548-5ad9087e61d6 is up.
# 2023-05-24 09:08:34,119|INFO|scheduler|push_log|143:
# Checking in the task ...
# 2023-05-24 09:08:35,127|INFO|scheduler|push_log|143:
# Node 6777d66c-08ac-4706-9548-5ad9087e61d6 have taken part in the task.
# 2023-05-24 09:08:35,128|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:35,128|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:48,151|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:08:48,151|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 1
# 2023-05-24 09:08:48,152|INFO|scheduler|push_log|143:
# Waiting for training of round 1 begin ...
# 2023-05-24 09:08:49,156|INFO|scheduler|push_log|143:
# Training of round 1 begins.
# 2023-05-24 09:08:49,156|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:08:50,472|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:08:50,475|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:08:50,475|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-images-idx3-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-images-idx3-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/train-images-idx3-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-labels-idx1-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/train-labels-idx1-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/train-labels-idx1-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-images-idx3-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-images-idx3-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/t10k-images-idx3-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw
#
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-labels-idx1-ubyte.gz
# Downloading https://alphamed-share-1309103037.cos.ap-beijing.myqcloud.com/dataset/t10k-labels-idx1-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw/t10k-labels-idx1-ubyte.gz to ./6777d66c-08ac-4706-9548-5ad9087e61d6/602476f9-7aec-4d6c-9524-fef10b768c2e/dataset/FedMNIST/raw
# 2023-05-24 09:08:54,236|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 3.761 秒
# 2023-05-24 09:08:54,238|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:08:54,238|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:08:54,243|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:08:55,445|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:08:55,446|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 1 ...
# 2023-05-24 09:08:58,454|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 1.
# 2023-05-24 09:08:58,454|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:08:58,455|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:08:58,460|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:08:58,460|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 2
# 2023-05-24 09:08:58,461|INFO|scheduler|push_log|143:
# Waiting for training of round 2 begin ...
# 2023-05-24 09:09:00,465|INFO|scheduler|push_log|143:
# Training of round 2 begins.
# 2023-05-24 09:09:00,466|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:00,780|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:00,784|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:00,785|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:02,661|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.876 秒
# 2023-05-24 09:09:02,662|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:02,663|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:02,667|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:03,870|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:03,870|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 2 ...
# 2023-05-24 09:09:05,875|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 2.
# 2023-05-24 09:09:05,876|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:05,876|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:05,881|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:05,882|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 3
# 2023-05-24 09:09:05,882|INFO|scheduler|push_log|143:
# Waiting for training of round 3 begin ...
# 2023-05-24 09:09:06,886|INFO|scheduler|push_log|143:
# Training of round 3 begins.
# 2023-05-24 09:09:06,887|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:07,200|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:07,203|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:07,203|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:09,062|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.858 秒
# 2023-05-24 09:09:09,063|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:09,063|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:09,068|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:10,270|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:10,271|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 3 ...
# 2023-05-24 09:09:11,274|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 3.
# 2023-05-24 09:09:11,275|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:11,275|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:11,281|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:11,281|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 4
# 2023-05-24 09:09:11,281|INFO|scheduler|push_log|143:
# Waiting for training of round 4 begin ...
# 2023-05-24 09:09:12,285|INFO|scheduler|push_log|143:
# Training of round 4 begins.
# 2023-05-24 09:09:12,286|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:12,600|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:12,603|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:12,603|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:14,453|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.849 秒
# 2023-05-24 09:09:14,454|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:14,454|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:14,459|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:15,661|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:15,662|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 4 ...
# 2023-05-24 09:09:16,666|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 4.
# 2023-05-24 09:09:16,667|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:16,667|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:16,672|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:16,673|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 5
# 2023-05-24 09:09:16,673|INFO|scheduler|push_log|143:
# Waiting for training of round 5 begin ...
# 2023-05-24 09:09:17,677|INFO|scheduler|push_log|143:
# Training of round 5 begins.
# 2023-05-24 09:09:17,678|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:18,998|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:19,002|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:19,003|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:20,883|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.880 秒
# 2023-05-24 09:09:20,884|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:20,885|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:20,889|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:21,991|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:21,992|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 5 ...
# 2023-05-24 09:09:23,997|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 5.
# 2023-05-24 09:09:23,998|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:23,998|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:24,003|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:24,004|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 6
# 2023-05-24 09:09:24,004|INFO|scheduler|push_log|143:
# Waiting for training of round 6 begin ...
# 2023-05-24 09:09:25,008|INFO|scheduler|push_log|143:
# Training of round 6 begins.
# 2023-05-24 09:09:25,009|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:25,326|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:25,331|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:25,331|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:27,212|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.880 秒
# 2023-05-24 09:09:27,213|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:27,214|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:27,218|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:28,321|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:28,321|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 6 ...
# 2023-05-24 09:09:29,325|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 6.
# 2023-05-24 09:09:29,326|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:29,326|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:29,332|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:29,332|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 7
# 2023-05-24 09:09:29,333|INFO|scheduler|push_log|143:
# Waiting for training of round 7 begin ...
# 2023-05-24 09:09:30,337|INFO|scheduler|push_log|143:
# Training of round 7 begins.
# 2023-05-24 09:09:30,338|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:30,651|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:30,655|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:30,655|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:32,447|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.792 秒
# 2023-05-24 09:09:32,448|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:32,449|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:32,454|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:33,557|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:33,557|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 7 ...
# 2023-05-24 09:09:35,563|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 7.
# 2023-05-24 09:09:35,563|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:35,564|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:35,569|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:35,569|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 8
# 2023-05-24 09:09:35,570|INFO|scheduler|push_log|143:
# Waiting for training of round 8 begin ...
# 2023-05-24 09:09:36,574|INFO|scheduler|push_log|143:
# Training of round 8 begins.
# 2023-05-24 09:09:36,574|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:36,897|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:36,899|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:36,900|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:38,769|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.868 秒
# 2023-05-24 09:09:38,770|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:38,771|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:38,775|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:39,877|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:39,878|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 8 ...
# 2023-05-24 09:09:40,882|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 8.
# 2023-05-24 09:09:40,883|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:40,883|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:40,889|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:40,890|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 9
# 2023-05-24 09:09:40,890|INFO|scheduler|push_log|143:
# Waiting for training of round 9 begin ...
# 2023-05-24 09:09:41,894|INFO|scheduler|push_log|143:
# Training of round 9 begins.
# 2023-05-24 09:09:41,895|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:42,209|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:42,211|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:42,211|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:44,018|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.806 秒
# 2023-05-24 09:09:44,019|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:44,020|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:44,024|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:45,227|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:45,228|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 9 ...
# 2023-05-24 09:09:48,234|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 9.
# 2023-05-24 09:09:48,234|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:48,235|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:48,240|INFO|scheduler|push_log|143:
# Successfully synchronized state with the aggregator.
# 2023-05-24 09:09:48,240|INFO|scheduler|push_log|143:
# Successfully synchronized state in round 10
# 2023-05-24 09:09:48,241|INFO|scheduler|push_log|143:
# Waiting for training of round 10 begin ...
# 2023-05-24 09:09:49,245|INFO|scheduler|push_log|143:
# Training of round 10 begins.
# 2023-05-24 09:09:49,246|INFO|scheduler|push_log|143:
# Waiting for receiving latest parameters from the aggregator ...
# 2023-05-24 09:09:49,666|INFO|scheduler|push_log|143:
# Successfully received latest parameters.
# 2023-05-24 09:09:49,670|INFO|scheduler|push_log|143:
# Saved latest parameters locally.
# 2023-05-24 09:09:49,671|INFO|scheduler|push_log|143:
# Begin to run calculation ...
# 2023-05-24 09:09:51,573|INFO|fed_prox_schd|train_an_epoch|62:
# 完成一轮训练，耗时 1.902 秒
# 2023-05-24 09:09:51,574|INFO|scheduler|push_log|143:
# Local calculation complete.
# 2023-05-24 09:09:51,575|INFO|scheduler|push_log|143:
# Waiting for aggregation begin ...
# 2023-05-24 09:09:51,579|INFO|scheduler|push_log|143:
# Pushing local update to the aggregator ...
# 2023-05-24 09:09:52,682|INFO|scheduler|push_log|143:
# Successfully pushed local update to the aggregator.
# 2023-05-24 09:09:52,682|INFO|scheduler|push_log|143:
# Waiting for closing signal of training round 10 ...
# 2023-05-24 09:09:54,687|INFO|scheduler|push_log|143:
# ID: 6777d66c-08ac-4706-9548-5ad9087e61d6 finished training task of round 10.
# 2023-05-24 09:09:54,687|INFO|scheduler|push_log|143:
# Synchronizing round state ...
# 2023-05-24 09:09:54,688|INFO|scheduler|push_log|143:
# Waiting for synchronizing state with the aggregator ...
# 2023-05-24 09:09:54,691|INFO|fed_avg|_launch_process|352:
# training task complete
